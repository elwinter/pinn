# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the initial conditions.
XY0 = np.loadtxt("data/sod2_nPux_101x101_IC.dat")

# %%
# Extract initial values.
t = XY0[:, 0]
x = XY0[:, 1]
n = XY0[:, 2]
P = XY0[:, 3]
ux = XY0[:, 4]

# %%
# Plot the initial number density.
plt.plot(x, n)
plt.xlabel("$x$")
plt.ylabel("$n$")
plt.title("Number density at t = 0")
# Out:
# Text(0.5, 1.0, 'Number density at t = 0')

# %%
# Plot the initial pressure.
plt.plot(x, P)
plt.xlabel("$x$")
plt.ylabel("$P$")
plt.title("Pressure at t = 0")
# Out:
# Text(0.5, 1.0, 'Pressure at t = 0')

# %%
# Plot the velocity at t = 0.
plt.plot(x, ux)
plt.xlabel("$x$")
plt.ylabel("$u_x$")
plt.title("$u_x$ at t = 0")
# Out:
# Text(0.5, 1.0, '$u_x$ at t = 0')
